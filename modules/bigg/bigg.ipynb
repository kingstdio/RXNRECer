# %% [markdown]
# # iML1515
#
# > author: Shizhenkun
# > email: zhenkun.shi@tib.cas.cn
# > date: 2024-11-27
#
#
# ## 1. Import packages

# %%
import sys,os
sys.path.insert(0, os.path.dirname(os.path.realpath('__file__')))
sys.path.insert(1,'../../')
sys.path.insert(1,'../methods/active-learning/')
from config import conf as cfg
from tools import uniprottool as uptool
from tools import  bioFunctionLib as bfl
from tqdm import tqdm
import re
from IPython.display import display_markdown
from pandarallel import pandarallel # 导入pandaralle
pandarallel.initialize(progress_bar=False)
from tkinter import _flatten
import json
import pandas as pd


FIRST_TIME_RUN = False # For the initial run, please set this flag to True. This will allow the program to download data from UniProt and RHEA, which may take longer depending on your internet speed.

# %load_ext autoreload
# %autoreload 2
# Out:
# INFO: Pandarallel will run on 128 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 2. 下载bigg数据

# %%
### 4.2  对比IML1515 gene
# 下载模型文件
if FIRST_TIME_RUN:
    ! wget -c http://bigg.ucsd.edu/static/models/iML1515.json
    ! wget -c http://bigg.ucsd.edu/static/namespace/bigg_models_reactions.txt
    
    
with open('iML1515.json', 'r', encoding='utf-8') as f:
    iml1515 = json.load(f)
    
iml1515_gene_ids = [gene['id'] for gene in iml1515['genes']]
print(f'Gene ids in iML1515: {len(iml1515_gene_ids)}')

rxn_bigg = pd.read_csv('bigg_models_reactions.txt', sep='\t')
rxn_bigg.head(3)
# Out:
# Gene ids in iML1515: 1516
#        bigg_id                                               name  \
# 0  DM_4crsol_c      Sink needed to allow p-Cresol to leave system
# 1  DM_aacald_c  Sink needed to allow aminoacetaldehyde to leav...
# 2    DM_amob_c  Sink needed to allow S-Adenosyl-4-methylthio-2...
#
#   reaction_string                                         model_list  \
# 0   4crsol_c <->   iEcDH1_1363; iJO1366; iE2348C_1286; iECB_1328;...
# 1   aacald_c <->   iECB_1328; iBWG_1329; iE2348C_1286; iECBD_1354...
# 2     amob_c <->   iECNA114_1301; iECDH10B_1368; iECP_1309; iECIA...
#
#                                       database_links  \
# 0  RHEA: http://identifiers.org/rhea/35071; RHEA:...
# 1  MetaNetX (MNX) Equation: http://identifiers.or...
# 2  MetaNetX (MNX) Equation: http://identifiers.or...
#
#                           old_bigg_ids
# 0               DM_4CRSOL; DM_4crsol_c
# 1  DM_AACALD; DM_aacald_c; R_DM_AACALD
# 2        DM_AMOB; DM_amob_c; sink_amob

# %% [markdown]
# ## 3. 提取RHHEA 映射关系

# %%
# 获取bigg数据库中rxn的rhea数据库链接
def get_bigg2rhea_link(link_str):
    if 'RHEA' not in str(link_str):
        return '-'
    else:
        rhea_ids = [f'RHEA:{item.rsplit("/", 1)[-1]}' for item in link_str.split('; ') if 'RHEA' in item]
        rhea_ids = [item.split('#')[0] if '#' in item else item for item in rhea_ids]
        rhea_ids = list(set(rhea_ids))
        return rhea_ids
    
    
get_bigg2rhea_link(link_str=rxn_bigg.database_links[0])
# Out:
# ['RHEA:35072', 'RHEA:35073', 'RHEA:35071', 'RHEA:35074']

# %%
# 获取bigg数据库中rxn的rhea数据库链接
rxn_bigg['rhea_link'] = rxn_bigg.database_links.parallel_apply(lambda x: get_bigg2rhea_link(x))
cross_ref_bigg2rhea =rxn_bigg[rxn_bigg.rhea_link!='-'].reset_index(drop=True)
cross_ref_bigg2rhea = cross_ref_bigg2rhea[['bigg_id', 'rhea_link']]

# %% [markdown]
# ## 4. 构建 rheaid2biggid字典, biggid2rheaid字典

# %%
# 构造 biggid2rheaid 字典
biggid2rheaid = cross_ref_bigg2rhea.set_index('bigg_id')['rhea_link'].to_dict()

# 构造 rheaid2biggid 字典
rheaid2biggid = {}
for bigg_id, rhea_ids in biggid2rheaid.items():
    for rhea_id in rhea_ids:
        rheaid2biggid.setdefault(rhea_id, []).append(bigg_id)

# 保存字典
os.makedirs(cfg.DIR_DICT, exist_ok=True)
with open(f'{cfg.DIR_DICT}dict_biggid2rheaid.json', 'w') as f:
    json.dump(biggid2rheaid, f, indent=4)
    
with open(f'{cfg.DIR_DICT}dict_rheaid2biggid.json', 'w') as f:
    json.dump(rheaid2biggid, f, indent=4)

# %%
rheaid2biggid
# Out:
# {'RHEA:35072': ['DM_4crsol_c', 'CREStex', 'EX_4crsol_e'],
#  'RHEA:35073': ['DM_4crsol_c', 'CREStex', 'EX_4crsol_e'],
#  'RHEA:35071': ['DM_4crsol_c', 'CREStex', 'EX_4crsol_e'],
#  'RHEA:35074': ['DM_4crsol_c', 'CREStex', 'EX_4crsol_e'],
#  'RHEA:34951': ['EX_3hpp_e', '3HPPtex'],
#  'RHEA:34952': ['EX_3hpp_e', '3HPPtex'],
#  'RHEA:34953': ['EX_3hpp_e', '3HPPtex'],
#  'RHEA:34954': ['EX_3hpp_e', '3HPPtex'],
#  'RHEA:35127': ['EX_LalaDglu_e', 'LALADGLUtex'],
#  'RHEA:35128': ['EX_LalaDglu_e', 'LALADGLUtex'],
#  'RHEA:35129': ['EX_LalaDglu_e', 'LALADGLUtex'],
#  'RHEA:35130': ['EX_LalaDglu_e', 'LALADGLUtex'],
#  'RHEA:35023': ['EX_arbt_e', 'ARBTtex'],
#  'RHEA:35026': ['EX_arbt_e', 'ARBTtex'],
#  'RHEA:35025': ['EX_arbt_e', 'ARBTtex'],
#  'RHEA:35024': ['EX_arbt_e', 'ARBTtex'],
#  'RHEA:28458': ['EX_btn_e', 'BTNtex', 'BTNtn', 'BTNTe'],
#  'RHEA:28461': ['EX_btn_e', 'BTNtex', 'BTNtn', 'BTNTe'],
#  'RHEA:28460': ['EX_btn_e', 'BTNtex', 'BTNtn', 'BTNTe'],
#  'RHEA:28459': ['EX_btn_e', 'BTNtex', 'BTNtn', 'BTNTe'],
#  'RHEA:29674': ['EX_ca2_e', 'CA2tex', 'SK_ca2_c', 'CA2t'],
#  'RHEA:29671': ['EX_ca2_e', 'CA2tex', 'SK_ca2_c', 'CA2t'],
#  'RHEA:29673': ['EX_ca2_e', 'CA2tex', 'SK_ca2_c', 'CA2t'],
#  'RHEA:29672': ['EX_ca2_e', 'CA2tex', 'SK_ca2_c', 'CA2t'],
#  'RHEA:29824': ['EX_cl_e', 'CLtex', 'Clt'],
#  'RHEA:29825': ['EX_cl_e', 'CLtex', 'Clt'],
#  'RHEA:29826': ['EX_cl_e', 'CLtex', 'Clt'],
#  'RHEA:29823': ['EX_cl_e', 'CLtex', 'Clt'],
#  'RHEA:35068': ['EX_crn__D_e', 'CRNDtex'],
#  'RHEA:35067': ['EX_crn__D_e', 'CRNDtex'],
#  'RHEA:35069': ['EX_crn__D_e', 'CRNDtex'],
#  'RHEA:35070': ['EX_crn__D_e', 'CRNDtex'],
#  'RHEA:28705': ['EX_cu2_e', 'CU2tex', 'CU2tpp'],
#  'RHEA:28703': ['EX_cu2_e', 'CU2tex', 'CU2tpp'],
#  'RHEA:28706': ['EX_cu2_e', 'CU2tex', 'CU2tpp'],
#  'RHEA:28704': ['EX_cu2_e', 'CU2tex', 'CU2tpp'],
#  'RHEA:29657': ['EX_cys__L_e', 'CYStpp', 'CYStex', 'CYStec', 'CYSth', 'r1437'],
#  'RHEA:29655': ['EX_cys__L_e', 'CYStpp', 'CYStex', 'CYStec', 'CYSth', 'r1437'],
#  'RHEA:29656': ['EX_cys__L_e', 'CYStpp', 'CYStex', 'CYStec', 'CYSth', 'r1437'],
#  'RHEA:29658': ['EX_cys__L_e', 'CYStpp', 'CYStex', 'CYStec', 'CYSth', 'r1437'],
#  'RHEA:29701': ['EX_dmso_e', 'DMSOtex', 'DMSOtpp'],
#  'RHEA:29699': ['EX_dmso_e', 'DMSOtex', 'DMSOtpp'],
#  'RHEA:29702': ['EX_dmso_e', 'DMSOtex', 'DMSOtpp'],
#  'RHEA:29700': ['EX_dmso_e', 'DMSOtex', 'DMSOtpp'],
#  'RHEA:35082': ['EX_doxrbcn_e', 'DOXRBCNtex'],
#  'RHEA:35079': ['EX_doxrbcn_e', 'DOXRBCNtex'],
#  'RHEA:35080': ['EX_doxrbcn_e', 'DOXRBCNtex'],
#  'RHEA:35081': ['EX_doxrbcn_e', 'DOXRBCNtex'],
#  'RHEA:28489': ['EX_fe2_e',
#   'FE2tex',
#   'FE2tpp',
#   'FEtm',
#   'FE2th',
#   'FE2t',
#   'FE2utm'],
#  'RHEA:28487': ['EX_fe2_e',
#   'FE2tex',
#   'FE2tpp',
#   'FEtm',
#   'FE2th',
#   'FE2t',
#   'FE2utm'],
#  'RHEA:28486': ['EX_fe2_e',
#   'FE2tex',
#   'FE2tpp',
#   'FEtm',
#   'FE2th',
#   'FE2t',
#   'FE2utm'],
#  'RHEA:28488': ['EX_fe2_e',
#   'FE2tex',
#   'FE2tpp',
#   'FEtm',
#   'FE2th',
#   'FE2t',
#   'FE2utm'],
#  'RHEA:34972': ['EX_fe3_e', 'FE3tex', 'FE3t'],
#  'RHEA:34973': ['EX_fe3_e', 'FE3tex', 'FE3t'],
#  'RHEA:34971': ['EX_fe3_e', 'FE3tex', 'FE3t'],
#  'RHEA:34974': ['EX_fe3_e', 'FE3tex', 'FE3t'],
#  'RHEA:28456': ['EX_frulys_e', 'FRULYStex'],
#  'RHEA:28457': ['EX_frulys_e', 'FRULYStex'],
#  'RHEA:28455': ['EX_frulys_e', 'FRULYStex'],
#  'RHEA:28454': ['EX_frulys_e', 'FRULYStex'],
#  'RHEA:32913': ['EX_g3pc_e', 'G3PCtex', 'G3PCt'],
#  'RHEA:32914': ['EX_g3pc_e', 'G3PCtex', 'G3PCt'],
#  'RHEA:32911': ['EX_g3pc_e', 'G3PCtex', 'G3PCt'],
#  'RHEA:32912': ['EX_g3pc_e', 'G3PCtex', 'G3PCt'],
#  'RHEA:34918': ['EX_gal_e', 'GALtly', 'GALtex', 'GALt1r'],
#  'RHEA:34916': ['EX_gal_e', 'GALtly', 'GALtex', 'GALt1r'],
#  'RHEA:34917': ['EX_gal_e', 'GALtly', 'GALtex', 'GALt1r'],
#  'RHEA:34915': ['EX_gal_e', 'GALtly', 'GALtex', 'GALt1r'],
#  'RHEA:28479': ['EX_galct__D_e', 'GALCTtex', 'EX_galctr__D_e'],
#  'RHEA:28480': ['EX_galct__D_e', 'GALCTtex', 'EX_galctr__D_e'],
#  'RHEA:28478': ['EX_galct__D_e', 'GALCTtex', 'EX_galctr__D_e'],
#  'RHEA:28481': ['EX_galct__D_e', 'GALCTtex', 'EX_galctr__D_e'],
#  'RHEA:32837': ['EX_gbbtn_e', 'GBBTNtex'],
#  'RHEA:32836': ['EX_gbbtn_e', 'GBBTNtex'],
#  'RHEA:32835': ['EX_gbbtn_e', 'GBBTNtex'],
#  'RHEA:32838': ['EX_gbbtn_e', 'GBBTNtex'],
#  'RHEA:28474': ['EX_glcr_e', 'GLCRtex'],
#  'RHEA:28475': ['EX_glcr_e', 'GLCRtex'],
#  'RHEA:28476': ['EX_glcr_e', 'GLCRtex'],
#  'RHEA:28477': ['EX_glcr_e', 'GLCRtex'],
#  'RHEA:34970': ['EX_glyc3p_e', 'GLYC3Ptm', 'GLYC3Ptex', 'GLYC3Pth', 'GLY3Pt'],
#  'RHEA:34968': ['EX_glyc3p_e', 'GLYC3Ptm', 'GLYC3Ptex', 'GLYC3Pth', 'GLY3Pt'],
#  'RHEA:34969': ['EX_glyc3p_e', 'GLYC3Ptm', 'GLYC3Ptex', 'GLYC3Pth', 'GLY3Pt'],
#  'RHEA:34967': ['EX_glyc3p_e', 'GLYC3Ptm', 'GLYC3Ptex', 'GLYC3Pth', 'GLY3Pt'],
#  'RHEA:45257': ['EX_hdca_e',
#   'FA160h',
#   'HDCAts',
#   'r0937',
#   'HDCAtexi',
#   'FA160tp',
#   'HDCAt',
#   'HDCAter'],
#  'RHEA:45256': ['EX_hdca_e',
#   'FA160h',
#   'HDCAts',
#   'r0937',
#   'HDCAtexi',
#   'FA160tp',
#   'HDCAt',
#   'HDCAter'],
#  'RHEA:45258': ['EX_hdca_e',
#   'FA160h',
#   'HDCAts',
#   'r0937',
#   'HDCAtexi',
#   'FA160tp',
#   'HDCAt',
#   'HDCAter'],
#  'RHEA:45259': ['EX_hdca_e',
#   'FA160h',
#   'HDCAts',
#   'r0937',
#   'HDCAtexi',
#   'FA160tp',
#   'HDCAt',
#   'HDCAter'],
#  'RHEA:32870': ['EX_inost_e', 'INSTtex', 'r0826'],
#  'RHEA:32869': ['EX_inost_e', 'INSTtex', 'r0826'],
#  'RHEA:32868': ['EX_inost_e', 'INSTtex', 'r0826'],
#  'RHEA:32867': ['EX_inost_e', 'INSTtex', 'r0826'],
#  'RHEA:29466': ['EX_k_e', 'Ktex', 'Kt1'],
#  'RHEA:29465': ['EX_k_e', 'Ktex', 'Kt1'],
#  'RHEA:29464': ['EX_k_e', 'Ktex', 'Kt1'],
#  'RHEA:29463': ['EX_k_e', 'Ktex', 'Kt1'],
#  'RHEA:34988': ['EX_lac__L_e', 'L_LACtex', 'L_LACtcm', 'LACLt'],
#  'RHEA:34989': ['EX_lac__L_e', 'L_LACtex', 'L_LACtcm', 'LACLt'],
#  'RHEA:34990': ['EX_lac__L_e', 'L_LACtex', 'L_LACtcm', 'LACLt'],
#  'RHEA:34987': ['EX_lac__L_e', 'L_LACtex', 'L_LACtcm', 'LACLt'],
#  'RHEA:29758': ['EX_lipoate_e', 'LIPOtex', 'EX_lipt_e'],
#  'RHEA:29756': ['EX_lipoate_e', 'LIPOtex', 'EX_lipt_e'],
#  'RHEA:29757': ['EX_lipoate_e', 'LIPOtex', 'EX_lipt_e'],
#  'RHEA:29755': ['EX_lipoate_e', 'LIPOtex', 'EX_lipt_e'],
#  'RHEA:34964': ['EX_na1_e',
#   'NAt',
#   'DM_na1_h',
#   'DM_na1_m',
#   'NA1tm',
#   'NAtex',
#   'NAtx',
#   'DM_na1_c',
#   'DM_na1_x',
#   'NA1th'],
#  'RHEA:34965': ['EX_na1_e',
#   'NAt',
#   'DM_na1_h',
#   'DM_na1_m',
#   'NA1tm',
#   'NAtex',
#   'NAtx',
#   'DM_na1_c',
#   'DM_na1_x',
#   'NA1th'],
#  'RHEA:34966': ['EX_na1_e',
#   'NAt',
#   'DM_na1_h',
#   'DM_na1_m',
#   'NA1tm',
#   'NAtex',
#   'NAtx',
#   'DM_na1_c',
#   'DM_na1_x',
#   'NA1th'],
#  'RHEA:34963': ['EX_na1_e',
#   'NAt',
#   'DM_na1_h',
#   'DM_na1_m',
#   'NA1tm',
#   'NAtex',
#   'NAtx',
#   'DM_na1_c',
#   'DM_na1_x',
#   'NA1th'],
#  'RHEA:28985': ['EX_no2_e', 'NO2th', 'NO2tex', 'NARK'],
#  'RHEA:28983': ['EX_no2_e', 'NO2th', 'NO2tex', 'NARK'],
#  'RHEA:28986': ['EX_no2_e', 'NO2th', 'NO2tex', 'NARK'],
#  'RHEA:28984': ['EX_no2_e', 'NO2th', 'NO2tex', 'NARK'],
#  'RHEA:34923': ['EX_no3_e', 'NO3tex', 'NO3t'],
#  'RHEA:34926': ['EX_no3_e', 'NO3tex', 'NO3t'],
#  'RHEA:34925': ['EX_no3_e', 'NO3tex', 'NO3t'],
#  'RHEA:34924': ['EX_no3_e', 'NO3tex', 'NO3t'],
#  'RHEA:33657': ['EX_ocdcea_e',
#   'OCDCEAtexi',
#   'OCDCEAt',
#   'FA18111Zh',
#   'r1301',
#   'r1302'],
#  'RHEA:33656': ['EX_ocdcea_e',
#   'OCDCEAtexi',
#   'OCDCEAt',
#   'FA18111Zh',
#   'r1301',
#   'r1302'],
#  'RHEA:33655': ['EX_ocdcea_e',
#   'OCDCEAtexi',
#   'OCDCEAt',
#   'FA18111Zh',
#   'r1301',
#   'r1302'],
#  'RHEA:33658': ['EX_ocdcea_e',
#   'OCDCEAtexi',
#   'OCDCEAt',
#   'FA18111Zh',
#   'r1301',
#   'r1302'],
#  'RHEA:34975': ['EX_pnto__R_e', 'PNTORtm', 'PNTOte', 'PNTOtex'],
#  'RHEA:34976': ['EX_pnto__R_e', 'PNTORtm', 'PNTOte', 'PNTOtex'],
#  'RHEA:34978': ['EX_pnto__R_e', 'PNTORtm', 'PNTOte', 'PNTOtex'],
#  'RHEA:34977': ['EX_pnto__R_e', 'PNTORtm', 'PNTOte', 'PNTOtex'],
#  'RHEA:29749': ['EX_pppn_e', 'PPPNtex'],
#  'RHEA:29750': ['EX_pppn_e', 'PPPNtex'],
#  'RHEA:29747': ['EX_pppn_e', 'PPPNtex'],
#  'RHEA:29748': ['EX_pppn_e', 'PPPNtex'],
#  'RHEA:28468': ['EX_pydam_e', 'PYDAMtex', 'PYDAMtpp', 'PYDAMtr'],
#  'RHEA:28467': ['EX_pydam_e', 'PYDAMtex', 'PYDAMtpp', 'PYDAMtr'],
#  'RHEA:28469': ['EX_pydam_e', 'PYDAMtex', 'PYDAMtpp', 'PYDAMtr'],
#  'RHEA:28466': ['EX_pydam_e', 'PYDAMtex', 'PYDAMtpp', 'PYDAMtr'],
#  'RHEA:28464': ['EX_pydx_e', 'PYDXtex', 'PYDXtpp', 'PYDXtr'],
#  'RHEA:28463': ['EX_pydx_e', 'PYDXtex', 'PYDXtpp', 'PYDXtr'],
#  'RHEA:28465': ['EX_pydx_e', 'PYDXtex', 'PYDXtpp', 'PYDXtr'],
#  'RHEA:28462': ['EX_pydx_e', 'PYDXtex', 'PYDXtpp', 'PYDXtr'],
#  'RHEA:34998': ['EX_rmn_e', 'RMNtex'],
#  'RHEA:34996': ['EX_rmn_e', 'RMNtex'],
#  'RHEA:34997': ['EX_rmn_e', 'RMNtex'],
#  'RHEA:34995': ['EX_rmn_e', 'RMNtex'],
#  'RHEA:34888': ['EX_sel_e', 'SELtex'],
#  'RHEA:34890': ['EX_sel_e', 'SELtex'],
#  'RHEA:34887': ['EX_sel_e', 'SELtex'],
#  'RHEA:34889': ['EX_sel_e', 'SELtex'],
#  'RHEA:29458': ['EX_ser__D_e', 'DSERtex'],
#  'RHEA:29455': ['EX_ser__D_e', 'DSERtex'],
#  'RHEA:29456': ['EX_ser__D_e', 'DSERtex'],
#  'RHEA:29457': ['EX_ser__D_e', 'DSERtex'],
#  'RHEA:34985': ['EX_so4_e', 'SO4tex', 'SO4ti', 'SO4tl', 'SO4tn'],
#  'RHEA:34984': ['EX_so4_e', 'SO4tex', 'SO4ti', 'SO4tl', 'SO4tn'],
#  'RHEA:34986': ['EX_so4_e', 'SO4tex', 'SO4ti', 'SO4tl', 'SO4tn'],
#  'RHEA:34983': ['EX_so4_e', 'SO4tex', 'SO4ti', 'SO4tl', 'SO4tn'],
#  'RHEA:35039': ['EX_spmd_e', 'SPMDtex2', 'SPMDtex'],
#  'RHEA:35041': ['EX_spmd_e', 'SPMDtex2', 'SPMDtex'],
#  'RHEA:35042': ['EX_spmd_e', 'SPMDtex2', 'SPMDtex'],
#  'RHEA:35040': ['EX_spmd_e', 'SPMDtex2', 'SPMDtex'],
#  'RHEA:35021': ['EX_thr__L_e', 'thr_mt', 'THRtex', 'r2534'],
#  'RHEA:35020': ['EX_thr__L_e', 'thr_mt', 'THRtex', 'r2534'],
#  'RHEA:35019': ['EX_thr__L_e', 'thr_mt', 'THRtex', 'r2534'],
#  'RHEA:35022': ['EX_thr__L_e', 'thr_mt', 'THRtex', 'r2534'],
#  'RHEA:35241': ['EX_ttrcyc_e', 'TTRCYCtex'],
#  'RHEA:35239': ['EX_ttrcyc_e', 'TTRCYCtex'],
#  'RHEA:35240': ['EX_ttrcyc_e', 'TTRCYCtex'],
#  'RHEA:35242': ['EX_ttrcyc_e', 'TTRCYCtex'],
#  'RHEA:32800': ['EX_urea_e',
#   'UREAt',
#   'UREAtm',
#   'UREAtex',
#   'UREAtpp',
#   'UREAt5'],
#  'RHEA:32802': ['EX_urea_e',
#   'UREAt',
#   'UREAtm',
#   'UREAtex',
#   'UREAtpp',
#   'UREAt5'],
#  'RHEA:32799': ['EX_urea_e',
#   'UREAt',
#   'UREAtm',
#   'UREAtex',
#   'UREAtpp',
#   'UREAt5'],
#  'RHEA:32801': ['EX_urea_e',
#   'UREAt',
#   'UREAtm',
#   'UREAtex',
#   'UREAtpp',
#   'UREAt5'],
#  'RHEA:29706': ['EX_val__L_e', 'VALtex', 'VALt5m', 'VALtec'],
#  'RHEA:29703': ['EX_val__L_e', 'VALtex', 'VALt5m', 'VALtec'],
#  'RHEA:29705': ['EX_val__L_e', 'VALtex', 'VALt5m', 'VALtec'],
#  'RHEA:29704': ['EX_val__L_e', 'VALtex', 'VALt5m', 'VALtec'],
#  'RHEA:29354': ['EX_zn2_e', 'Zn2tex', 'EX_HC02172_e', 'ZN2tpp', 'r2465'],
#  'RHEA:29351': ['EX_zn2_e', 'Zn2tex', 'EX_HC02172_e', 'ZN2tpp', 'r2465'],
#  'RHEA:29353': ['EX_zn2_e', 'Zn2tex', 'EX_HC02172_e', 'ZN2tpp', 'r2465'],
#  'RHEA:29352': ['EX_zn2_e', 'Zn2tex', 'EX_HC02172_e', 'ZN2tpp', 'r2465'],
#  'RHEA:27881': ['23PDE2pp', '23CN2P2', 'RE1860E'],
#  'RHEA:27879': ['23PDE2pp', '23CN2P2', 'RE1860E'],
#  'RHEA:27880': ['23PDE2pp', '23CN2P2', 'RE1860E'],
#  'RHEA:27878': ['23PDE2pp', '23CN2P2', 'RE1860E'],
#  'RHEA:27861': ['23PDE9pp', '23CN2P4'],
#  'RHEA:27860': ['23PDE9pp', '23CN2P4'],
#  'RHEA:27859': ['23PDE9pp', '23CN2P4'],
#  'RHEA:27858': ['23PDE9pp', '23CN2P4'],
#  'RHEA:28222': ['3KGK'],
#  'RHEA:28225': ['3KGK'],
#  'RHEA:28224': ['3KGK'],
#  'RHEA:28223': ['3KGK'],
#  'RHEA:27890': ['3NTD2pp', '3NUCLE2'],
#  'RHEA:27891': ['3NTD2pp', '3NUCLE2'],
#  'RHEA:27892': ['3NTD2pp', '3NUCLE2'],
#  'RHEA:27893': ['3NTD2pp', '3NUCLE2'],
#  'RHEA:27864': ['3NTD9pp', '3NUCLE4'],
#  'RHEA:27865': ['3NTD9pp', '3NUCLE4'],
#  'RHEA:27863': ['3NTD9pp', '3NUCLE4'],
#  'RHEA:27862': ['3NTD9pp', '3NUCLE4'],
#  'RHEA:30661': ['4HTHRS'],
#  'RHEA:30659': ['4HTHRS'],
#  'RHEA:30662': ['4HTHRS'],
#  'RHEA:30660': ['4HTHRS'],
#  'RHEA:28822': ['5DGLCNt2rpp'],
#  'RHEA:28821': ['5DGLCNt2rpp'],
#  'RHEA:28820': ['5DGLCNt2rpp'],
#  'RHEA:28819': ['5DGLCNt2rpp'],
#  'RHEA:29862': ['5DOAN'],
#  'RHEA:29861': ['5DOAN'],
#  'RHEA:29860': ['5DOAN'],
#  'RHEA:29859': ['5DOAN'],
#  'RHEA:34957': ['5MTRtex', 'EX_5mtr_e'],
#  'RHEA:34958': ['5MTRtex', 'EX_5mtr_e'],
#  'RHEA:34956': ['5MTRtex', 'EX_5mtr_e'],
#  'RHEA:34955': ['5MTRtex', 'EX_5mtr_e'],
#  'RHEA:23107': ['A5PISO'],
#  'RHEA:23104': ['A5PISO'],
#  'RHEA:23106': ['A5PISO'],
#  'RHEA:23105': ['A5PISO'],
#  'RHEA:23352': ['ABTA', 'ABTArm'],
#  'RHEA:23355': ['ABTA', 'ABTArm'],
#  'RHEA:23353': ['ABTA', 'ABTArm'],
#  'RHEA:23354': ['ABTA', 'ABTArm'],
#  'RHEA:28915': ['ABUTt2pp', 'ABUTt2r', 'ABUTt2rL', '4ABUTthi', '4ABUTtmi'],
#  'RHEA:28918': ['ABUTt2pp', 'ABUTt2r', 'ABUTt2rL', '4ABUTthi', '4ABUTtmi'],
#  'RHEA:28917': ['ABUTt2pp', 'ABUTt2r', 'ABUTt2rL', '4ABUTthi', '4ABUTtmi'],
#  'RHEA:28916': ['ABUTt2pp', 'ABUTt2r', 'ABUTt2rL', '4ABUTthi', '4ABUTtmi'],
#  'RHEA:31111': ['ACACT2r', 'ACACT2', 'ACACT2m'],
#  'RHEA:31114': ['ACACT2r', 'ACACT2', 'ACACT2m'],
#  'RHEA:31113': ['ACACT2r', 'ACACT2', 'ACACT2m'],
#  'RHEA:31112': ['ACACT2r', 'ACACT2', 'ACACT2m'],
#  'RHEA:31087': ['ACACT4r', 'ACACT4p', 'ACACT4m'],
#  'RHEA:31089': ['ACACT4r', 'ACACT4p', 'ACACT4m'],
#  'RHEA:31090': ['ACACT4r', 'ACACT4p', 'ACACT4m'],
#  'RHEA:31088': ['ACACT4r', 'ACACT4p', 'ACACT4m'],
#  'RHEA:29751': ['ACACtex', 'ACACtx', 'ACACtm', 'EX_acac_e'],
#  'RHEA:29754': ['ACACtex', 'ACACtx', 'ACACtm', 'EX_acac_e'],
#  'RHEA:29753': ['ACACtex', 'ACACtx', 'ACACtm', 'EX_acac_e'],
#  'RHEA:29752': ['ACACtex', 'ACACtx', 'ACACtm', 'EX_acac_e'],
#  'RHEA:22713': ['ACBIPGT'],
#  'RHEA:22714': ['ACBIPGT'],
#  'RHEA:22712': ['ACBIPGT'],
#  'RHEA:22715': ['ACBIPGT'],
#  'RHEA:24293': ['ACGS', 'ACGSm'],
#  'RHEA:24294': ['ACGS', 'ACGSm'],
#  'RHEA:24292': ['ACGS', 'ACGSm'],
#  'RHEA:24295': ['ACGS', 'ACGSm'],
#  'RHEA:25249': ['ACLS', 'ACLSm', 'PPATDh'],
#  'RHEA:25251': ['ACLS', 'ACLSm', 'PPATDh'],
#  'RHEA:25252': ['ACLS', 'ACLSm', 'PPATDh'],
#  'RHEA:25250': ['ACLS', 'ACLSm', 'PPATDh'],
#  'RHEA:28366': ['ACMAMUT'],
#  'RHEA:28369': ['ACMAMUT'],
#  'RHEA:28368': ['ACMAMUT'],
#  'RHEA:28367': ['ACMAMUT'],
#  'RHEA:28989': ['ACNAMt2pp', 'ACNAMt2', 'ACNAMlt'],
#  'RHEA:28990': ['ACNAMt2pp', 'ACNAMt2', 'ACNAMlt'],
#  'RHEA:28988': ['ACNAMt2pp', 'ACNAMt2', 'ACNAMlt'],
#  'RHEA:28987': ['ACNAMt2pp', 'ACNAMt2', 'ACNAMlt'],
#  'RHEA:23296': ['ACNML'],
#  'RHEA:23299': ['ACNML'],
#  'RHEA:23297': ['ACNML'],
#  'RHEA:23298': ['ACNML'],
#  'RHEA:30731': ['ACOAD1f', 'ACOA40OR', 'ACOAD1fm'],
#  'RHEA:24006': ['ACOAD1f', 'ACOA40OR', 'ACOAD1fm'],
#  'RHEA:30733': ['ACOAD1f', 'ACOA40OR', 'ACOAD1fm'],
#  'RHEA:24005': ['ACOAD1f', 'ACOA40OR', 'ACOAD1fm'],
#  'RHEA:30734': ['ACOAD1f', 'ACOA40OR', 'ACOAD1fm'],
#  'RHEA:24007': ['ACOAD1f', 'ACOA40OR', 'ACOAD1fm'],
#  'RHEA:24004': ['ACOAD1f', 'ACOA40OR', 'ACOAD1fm'],
#  'RHEA:30732': ['ACOAD1f', 'ACOA40OR', 'ACOAD1fm'],
#  'RHEA:31039': ['ACOAD5f', 'ACOA120OR'],
#  'RHEA:47296': ['ACOAD5f', 'ACOA120OR'],
#  'RHEA:31040': ['ACOAD5f', 'ACOA120OR'],
#  'RHEA:31042': ['ACOAD5f', 'ACOA120OR'],
#  'RHEA:47297': ['ACOAD5f', 'ACOA120OR'],
#  'RHEA:47298': ['ACOAD5f', 'ACOA120OR'],
#  'RHEA:47299': ['ACOAD5f', 'ACOA120OR'],
#  'RHEA:31041': ['ACOAD5f', 'ACOA120OR'],
#  'RHEA:43448': ['ACOAD7f', 'ACOA160OR'],
#  'RHEA:30750': ['ACOAD7f', 'ACOA160OR'],
#  'RHEA:30747': ['ACOAD7f', 'ACOA160OR'],
#  'RHEA:43451': ['ACOAD7f', 'ACOA160OR'],
#  'RHEA:43450': ['ACOAD7f', 'ACOA160OR'],
#  'RHEA:30748': ['ACOAD7f', 'ACOA160OR'],
#  'RHEA:30749': ['ACOAD7f', 'ACOA160OR'],
#  'RHEA:43449': ['ACOAD7f', 'ACOA160OR'],
#  'RHEA:40845': ['ACOAD8f'],
#  'RHEA:47243': ['ACOAD8f'],
#  'RHEA:47241': ['ACOAD8f'],
#  'RHEA:40843': ['ACOAD8f'],
#  'RHEA:47240': ['ACOAD8f'],
#  'RHEA:40846': ['ACOAD8f'],
#  'RHEA:47242': ['ACOAD8f'],
#  'RHEA:40844': ['ACOAD8f'],
#  'RHEA:15942': ['ACODA', 'ACODA_1'],
#  'RHEA:15943': ['ACODA', 'ACODA_1'],
#  'RHEA:15944': ['ACODA', 'ACODA_1'],
#  'RHEA:15941': ['ACODA', 'ACODA_1'],
#  'RHEA:17266': ['ACONIs'],
#  'RHEA:17267': ['ACONIs'],
#  'RHEA:17268': ['ACONIs'],
#  'RHEA:17265': ['ACONIs'],
#  'RHEA:14972': ['ACONMT'],
#  'RHEA:14969': ['ACONMT'],
#  'RHEA:14971': ['ACONMT'],
#  'RHEA:14970': ['ACONMT'],
#  'RHEA:18051': ['ACOTA', 'ACOTAim'],
#  'RHEA:18049': ['ACOTA', 'ACOTAim'],
#  'RHEA:18052': ['ACOTA', 'ACOTAim'],
#  'RHEA:18050': ['ACOTA', 'ACOTAim'],
#  'RHEA:29661': ['ACSERtpp', 'EX_acser_e', 'ACSERtex', 'ACSERthi', 'ACSERtmi'],
#  'RHEA:29662': ['ACSERtpp', 'EX_acser_e', 'ACSERtex', 'ACSERthi', 'ACSERtmi'],
#  'RHEA:29659': ['ACSERtpp', 'EX_acser_e', 'ACSERtex', 'ACSERthi', 'ACSERtmi'],
#  'RHEA:29660': ['ACSERtpp', 'EX_acser_e', 'ACSERtex', 'ACSERthi', 'ACSERtmi'],
#  'RHEA:27814': ['ACtex',
#   'ACtm',
#   'ACts',
#   'EX_ac_e',
#   'ACtp',
#   'ACtr',
#   'ACtg',
#   'ACth'],
#  'RHEA:27816': ['ACtex',
#   'ACtm',
#   'ACts',
#   'EX_ac_e',
#   'ACtp',
#   'ACtr',
#   'ACtg',
#   'ACth'],
#  'RHEA:27817': ['ACtex',
#   'ACtm',
#   'ACts',
#   'EX_ac_e',
#   'ACtp',
#   'ACtr',
#   'ACtg',
#   'ACth'],
#  'RHEA:27815': ['ACtex',
#   'ACtm',
#   'ACts',
#   'EX_ac_e',
#   'ACtp',
#   'ACtr',
#   'ACtg',
#   'ACth'],
#  'RHEA:16201': ['ADCL'],
#  'RHEA:16203': ['ADCL'],
#  'RHEA:16204': ['ADCL'],
#  'RHEA:16202': ['ADCL'],
#  'RHEA:11674': ['ADCS'],
#  'RHEA:11673': ['ADCS'],
#  'RHEA:11675': ['ADCS'],
#  'RHEA:11672': ['ADCS'],
#  'RHEA:23690': ['ADD'],
#  'RHEA:23689': ['ADD'],
#  'RHEA:23688': ['ADD'],
#  'RHEA:23691': ['ADD'],
#  'RHEA:28720': ['ADEt2rpp', 'ADEt2'],
#  'RHEA:28722': ['ADEt2rpp', 'ADEt2'],
#  'RHEA:28721': ['ADEt2rpp', 'ADEt2'],
#  'RHEA:28719': ['ADEt2rpp', 'ADEt2'],
#  'RHEA:29864': ['ADK3', 'ADK3m'],
#  'RHEA:29865': ['ADK3', 'ADK3m'],
#  'RHEA:29866': ['ADK3', 'ADK3m'],
#  'RHEA:29863': ['ADK3', 'ADK3m'],
#  'RHEA:15392': ['ADNCYC', 'ADECn'],
#  'RHEA:15390': ['ADNCYC', 'ADECn'],
#  'RHEA:15391': ['ADNCYC', 'ADECn'],
#  'RHEA:15389': ['ADNCYC', 'ADECn'],
#  'RHEA:20824': ['ADNK1', 'ADNK1n', 'ADNK1m'],
#  'RHEA:20826': ['ADNK1', 'ADNK1n', 'ADNK1m'],
#  'RHEA:20827': ['ADNK1', 'ADNK1n', 'ADNK1m'],
#  'RHEA:20825': ['ADNK1', 'ADNK1n', 'ADNK1m'],
#  'RHEA:18669': ['ADNUC'],
#  'RHEA:18671': ['ADNUC'],
#  'RHEA:18670': ['ADNUC'],
#  'RHEA:18672': ['ADNUC'],
#  'RHEA:29988': ['ADNt2pp', 'ADNt2'],
#  'RHEA:29990': ['ADNt2pp', 'ADNt2'],
#  'RHEA:29989': ['ADNt2pp', 'ADNt2'],
#  'RHEA:29987': ['ADNt2pp', 'ADNt2'],
#  'RHEA:16612': ['ADPT', 'r0051'],
#  'RHEA:16609': ['ADPT', 'r0051'],
#  'RHEA:16611': ['ADPT', 'r0051'],
#  'RHEA:16610': ['ADPT', 'r0051'],
#  'RHEA:24152': ['ADSK', 'AASPh', 'AASPm', 'ADSKn'],
#  'RHEA:24153': ['ADSK', 'AASPh', 'AASPm', 'ADSKn'],
#  'RHEA:24154': ['ADSK', 'AASPh', 'AASPm', 'ADSKn'],
#  'RHEA:24155': ['ADSK', 'AASPh', 'AASPm', 'ADSKn'],
#  'RHEA:15753': ['ADSS', 'ADSSh'],
#  'RHEA:15754': ['ADSS', 'ADSSh'],
#  'RHEA:15755': ['ADSS', 'ADSSh'],
#  'RHEA:15756': ['ADSS', 'ADSSh'],
#  'RHEA:13930': ['AGMT', 'AGMTm'],
#  'RHEA:13932': ['AGMT', 'AGMTm'],
#  'RHEA:13931': ['AGMT', 'AGMTm'],
#  'RHEA:13929': ['AGMT', 'AGMTm'],
#  'RHEA:19320': ['AIRC2'],
#  'RHEA:19319': ['AIRC2'],
#  'RHEA:19317': ['AIRC2'],
#  'RHEA:19318': ['AIRC2'],
#  'RHEA:11224': ['ALAALAr'],
#  'RHEA:11227': ['ALAALAr'],
#  'RHEA:11225': ['ALAALAr'],
#  'RHEA:11226': ['ALAALAr'],
#  'RHEA:28564': ['ALATA_D2'],
#  'RHEA:28562': ['ALATA_D2'],
#  'RHEA:28563': ['ALATA_D2'],
#  'RHEA:28565': ['ALATA_D2'],
#  'RHEA:19454': ['ALATA_L', 'ALATA_Lm'],
#  'RHEA:19456': ['ALATA_L', 'ALATA_Lm'],
#  'RHEA:19453': ['ALATA_L', 'ALATA_Lm'],
#  'RHEA:19455': ['ALATA_L', 'ALATA_Lm'],
#  'RHEA:30023': ['ALATA_L2'],
#  'RHEA:30024': ['ALATA_L2'],
#  'RHEA:30025': ['ALATA_L2'],
#  'RHEA:30026': ['ALATA_L2'],
#  'RHEA:29446': ['ALAt2pp', 'ALAtx', 'ALAt2r', 'ALAt2rL', 'ALAtm'],
#  'RHEA:29444': ['ALAt2pp', 'ALAtx', 'ALAt2r', 'ALAt2rL', 'ALAtm'],
#  'RHEA:29443': ['ALAt2pp', 'ALAtx', 'ALAt2r', 'ALAt2rL', 'ALAtm'],
#  'RHEA:29445': ['ALAt2pp', 'ALAtx', 'ALAt2r', 'ALAt2rL', 'ALAtm'],
#  'RHEA:25290': ['ALCD2x', 'ALCD2ir', 'ALCD2irm'],
#  'RHEA:25291': ['ALCD2x', 'ALCD2ir', 'ALCD2irm'],
#  'RHEA:25293': ['ALCD2x', 'ALCD2ir', 'ALCD2irm'],
#  'RHEA:25292': ['ALCD2x', 'ALCD2ir', 'ALCD2irm'],
#  'RHEA:32280': ['ALLTAMH'],
#  'RHEA:32282': ['ALLTAMH'],
#  'RHEA:32281': ['ALLTAMH'],
#  'RHEA:32279': ['ALLTAMH'],
#  'RHEA:15960': ['ALTRH'],
#  'RHEA:15959': ['ALTRH'],
#  'RHEA:15958': ['ALTRH'],
#  'RHEA:15957': ['ALTRH'],
#  'RHEA:25260': ['AMANAPEr'],
#  'RHEA:25258': ['AMANAPEr'],
#  'RHEA:25259': ['AMANAPEr'],
#  'RHEA:25257': ['AMANAPEr'],
#  'RHEA:25253': ['AMANK'],
#  'RHEA:25254': ['AMANK'],
#  'RHEA:25255': ['AMANK'],
#  'RHEA:25256': ['AMANK'],
#  'RHEA:16861': ['AMAOTr'],
#  'RHEA:16864': ['AMAOTr'],
#  'RHEA:16862': ['AMAOTr'],
#  'RHEA:16863': ['AMAOTr'],
#  'RHEA:11768': ['ANPRT', 'ANTPPT'],
#  'RHEA:11771': ['ANPRT', 'ANTPPT'],
#  'RHEA:11769': ['ANPRT', 'ANTPPT'],
#  'RHEA:11770': ['ANPRT', 'ANTPPT'],
#  'RHEA:34936': ['AP4AS'],
#  'RHEA:34935': ['AP4AS'],
#  'RHEA:34937': ['AP4AS'],
#  'RHEA:34938': ['AP4AS'],
#  'RHEA:30527': ['AP5AH'],
#  'RHEA:30530': ['AP5AH'],
#  'RHEA:30529': ['AP5AH'],
#  'RHEA:30528': ['AP5AH'],
#  'RHEA:29651': ['ARGAGMt7pp'],
#  'RHEA:29653': ['ARGAGMt7pp'],
#  'RHEA:29654': ['ARGAGMt7pp'],
#  'RHEA:29652': ['ARGAGMt7pp'],
#  'RHEA:17644': ['ARGDC', 'ARGDCpp', 'ARGDCm'],
#  'RHEA:17642': ['ARGDC', 'ARGDCpp', 'ARGDCm'],
#  'RHEA:17643': ['ARGDC', 'ARGDCpp', 'ARGDCm'],
#  'RHEA:17641': ['ARGDC', 'ARGDCpp', 'ARGDCm'],
#  'RHEA:10933': ['ARGSS', 'ARGSS_1'],
#  'RHEA:10935': ['ARGSS', 'ARGSS_1'],
#  'RHEA:10934': ['ARGSS', 'ARGSS_1'],
#  'RHEA:10932': ['ARGSS', 'ARGSS_1'],
#  'RHEA:32144': ['ARGtex', 'ARGt5r', 'EX_arg__L_e', 'ARG_Ltm'],
#  'RHEA:32146': ['ARGtex', 'ARGt5r', 'EX_arg__L_e', 'ARG_Ltm'],
#  'RHEA:32143': ['ARGtex', 'ARGt5r', 'EX_arg__L_e', 'ARG_Ltm'],
#  'RHEA:32145': ['ARGtex', 'ARGt5r', 'EX_arg__L_e', 'ARG_Ltm'],
#  'RHEA:24284': ['ASAD', 'ASADH'],
#  'RHEA:24286': ['ASAD', 'ASADH'],
#  'RHEA:24285': ['ASAD', 'ASADH'],
#  'RHEA:24287': ['ASAD', 'ASADH'],
#  'RHEA:28806': ['ASCBPL'],
#  'RHEA:28805': ['ASCBPL'],
#  'RHEA:28803': ['ASCBPL'],
#  'RHEA:28804': ['ASCBPL'],
#  'RHEA:21017': ['ASNN', 'ASNNpp', 'ASNNe', 'ASNNm', 'ASPSE'],
#  'RHEA:21016': ['ASNN', 'ASNNpp', 'ASNNe', 'ASNNm', 'ASPSE'],
#  'RHEA:21019': ['ASNN', 'ASNNpp', 'ASNNe', 'ASNNm', 'ASPSE'],
#  'RHEA:21018': ['ASNN', 'ASNNpp', 'ASNNe', 'ASNNm', 'ASPSE'],
#  'RHEA:11375': ['ASNS2'],
#  'RHEA:11374': ['ASNS2'],
#  'RHEA:11372': ['ASNS2'],
#  'RHEA:11373': ['ASNS2'],
#  'RHEA:28686': ['ASPO3', 'ASPO3_1'],
#  'RHEA:28683': ['ASPO3', 'ASPO3_1'],
#  'RHEA:28684': ['ASPO3', 'ASPO3_1'],
#  'RHEA:28685': ['ASPO3', 'ASPO3_1'],
#  'RHEA:29191': ['ASPO4', 'ASPO4_1'],
#  'RHEA:29194': ['ASPO4', 'ASPO4_1'],
#  'RHEA:29192': ['ASPO4', 'ASPO4_1'],
#  'RHEA:29193': ['ASPO4', 'ASPO4_1'],
#  'RHEA:16601': ['ASPT'],
#  'RHEA:16603': ['ASPT'],
#  'RHEA:16602': ['ASPT'],
#  'RHEA:16604': ['ASPT'],
#  'RHEA:21826': ['ASPTA', 'ASPTAm', 'ASPATh', 'ASPTAp'],
#  'RHEA:21825': ['ASPTA', 'ASPTAm', 'ASPATh', 'ASPTAp'],
#  'RHEA:21827': ['ASPTA', 'ASPTAm', 'ASPATh', 'ASPTAp'],
#  'RHEA:21824': ['ASPTA', 'ASPTAm', 'ASPATh', 'ASPTAp'],
#  'RHEA:29039': ['ASPabcpp', 'ASPabc'],
#  'RHEA:29040': ['ASPabcpp', 'ASPabc'],
#  'RHEA:29041': ['ASPabcpp', 'ASPabc'],
#  'RHEA:29042': ['ASPabcpp', 'ASPabc'],
#  'RHEA:29290': ['ASPt2_2pp', 'ASPt2_2'],
#  'RHEA:29287': ['ASPt2_2pp', 'ASPt2_2'],
#  'RHEA:29289': ['ASPt2_2pp', 'ASPt2_2'],
#  'RHEA:29288': ['ASPt2_2pp', 'ASPt2_2'],
#  'RHEA:15188': ['AST'],
#  'RHEA:15187': ['AST'],
#  'RHEA:15186': ['AST'],
#  'RHEA:15185': ['AST'],
#  'RHEA:30056': ['ATHRDHr'],
#  'RHEA:30058': ['ATHRDHr'],
#  'RHEA:30057': ['ATHRDHr'],
#  'RHEA:30055': ['ATHRDHr'],
#  'RHEA:13037': ['ATPHs'],
#  'RHEA:13039': ['ATPHs'],
#  'RHEA:13038': ['ATPHs'],
#  'RHEA:13040': ['ATPHs'],
#  'RHEA:13068': ['ATPM', 'NTP1', 'ATPPHm', 'ATPS'],
#  'RHEA:13065': ['ATPM', 'NTP1', 'ATPPHm', 'ATPS'],
#  'RHEA:13067': ['ATPM', 'NTP1', 'ATPPHm', 'ATPS'],
#  'RHEA:13066': ['ATPM', 'NTP1', 'ATPPHm', 'ATPS'],
#  'RHEA:29460': ['BALAt2pp', 'BALAt2r'],
#  'RHEA:29462': ['BALAt2pp', 'BALAt2r'],
#  'RHEA:29459': ['BALAt2pp', 'BALAt2r'],
#  'RHEA:29461': ['BALAt2pp', 'BALAt2r'],
#  'RHEA:15307': ['BETALDHx', 'BETALDHxm'],
#  'RHEA:15306': ['BETALDHx', 'BETALDHxm'],
#  'RHEA:15308': ['BETALDHx', 'BETALDHxm'],
#  'RHEA:15305': ['BETALDHx', 'BETALDHxm'],
#  'RHEA:10152': ['CBMKr'],
#  'RHEA:10153': ['CBMKr'],
#  'RHEA:10155': ['CBMKr'],
#  'RHEA:10154': ['CBMKr'],
#  'RHEA:18636': ['CBPS', 'HCGALm', 'CBPSn'],
#  'RHEA:18633': ['CBPS', 'HCGALm', 'CBPSn'],
#  'RHEA:18635': ['CBPS', 'HCGALm', 'CBPSn'],
#  'RHEA:18634': ['CBPS', 'HCGALm', 'CBPSn'],
#  'RHEA:27983': ['CCGS'],
#  'RHEA:27984': ['CCGS'],
#  'RHEA:27982': ['CCGS'],
#  'RHEA:27985': ['CCGS'],
#  'RHEA:12134': ['CD2abcpp', 'CD2abc1', 'CD2abc2'],
#  'RHEA:12132': ['CD2abcpp', 'CD2abc1', 'CD2abc2'],
#  'RHEA:12135': ['CD2abcpp', 'CD2abc1', 'CD2abc2'],
#  'RHEA:12133': ['CD2abcpp', 'CD2abc1', 'CD2abc2'],
#  'RHEA:28741': ['CD2t3pp'],
#  'RHEA:28742': ['CD2t3pp'],
#  'RHEA:28739': ['CD2t3pp'],
#  'RHEA:28740': ['CD2t3pp'],
#  'RHEA:13411': ['CDGR'],
#  'RHEA:13412': ['CDGR'],
#  'RHEA:13409': ['CDGR'],
#  'RHEA:13410': ['CDGR'],
#  'RHEA:18440': ['CDPMEK', 'CMK'],
#  'RHEA:18438': ['CDPMEK', 'CMK'],
#  'RHEA:18437': ['CDPMEK', 'CMK'],
#  'RHEA:18439': ['CDPMEK', 'CMK'],
#  'RHEA:28845': ['CHLt2pp', 'CHLt2'],
#  'RHEA:28846': ['CHLt2pp', 'CHLt2'],
#  'RHEA:28843': ['CHLt2pp', 'CHLt2'],
#  'RHEA:28844': ['CHLt2pp', 'CHLt2'],
#  'RHEA:13897': ['CHORM', 'CHRM'],
#  'RHEA:13899': ['CHORM', 'CHRM'],
#  'RHEA:13900': ['CHORM', 'CHRM'],
#  'RHEA:13898': ['CHORM', 'CHRM'],
#  'RHEA:16505': ['CHRPL'],
#  'RHEA:16506': ['CHRPL'],
#  'RHEA:16508': ['CHRPL'],
#  'RHEA:16507': ['CHRPL'],
#  'RHEA:25060': ['CINNDO'],
#  'RHEA:25061': ['CINNDO'],
#  'RHEA:25058': ['CINNDO'],
#  'RHEA:25059': ['CINNDO'],
#  'RHEA:10762': ['CITL', 'r1109'],
#  'RHEA:10761': ['CITL', 'r1109'],
#  'RHEA:10763': ['CITL', 'r1109'],
#  'RHEA:10760': ['CITL', 'r1109'],
#  'RHEA:33185': ['CITtex', 'CITtupp', 'EX_cit_e', 'CITx'],
#  'RHEA:33184': ['CITtex', 'CITtupp', 'EX_cit_e', 'CITx'],
#  'RHEA:33186': ['CITtex', 'CITtupp', 'EX_cit_e', 'CITx'],
#  'RHEA:33183': ['CITtex', 'CITtupp', 'EX_cit_e', 'CITx'],
#  'RHEA:29568': ['CLt3_2pp', 'CLt3r_2'],
#  'RHEA:29569': ['CLt3_2pp', 'CLt3r_2'],
#  'RHEA:29567': ['CLt3_2pp', 'CLt3r_2'],
#  'RHEA:29570': ['CLt3_2pp', 'CLt3r_2'],
#  'RHEA:32779': ['COBALT2abcpp', 'COabc', 'Cobalt2abcppI'],
#  'RHEA:32782': ['COBALT2abcpp', 'COabc', 'Cobalt2abcppI'],
#  'RHEA:32780': ['COBALT2abcpp', 'COabc', 'Cobalt2abcppI'],
#  'RHEA:32781': ['COBALT2abcpp', 'COabc', 'Cobalt2abcppI'],
#  'RHEA:28418': ['CRNBTCT'],
#  'RHEA:28419': ['CRNBTCT'],
#  'RHEA:28420': ['CRNBTCT'],
#  'RHEA:28421': ['CRNBTCT'],
#  'RHEA:30545': ['CRNDCAL2'],
#  'RHEA:30543': ['CRNDCAL2'],
#  'RHEA:30546': ['CRNDCAL2'],
#  'RHEA:30544': ['CRNDCAL2'],
#  'RHEA:34959': ['CRNtex', 'CRNtim', 'EX_crn_e', 'CRNt', 'CRNtp', 'r0002'],
#  'RHEA:34962': ['CRNtex', 'CRNtim', 'EX_crn_e', 'CRNt', 'CRNtp', 'r0002'],
#  'RHEA:34961': ['CRNtex', 'CRNtim', 'EX_crn_e', 'CRNt', 'CRNtp', 'r0002'],
#  'RHEA:34960': ['CRNtex', 'CRNtim', 'EX_crn_e', 'CRNt', 'CRNtp', 'r0002'],
#  'RHEA:16846': ['CS', 'CSm', 'CSp'],
#  'RHEA:16847': ['CS', 'CSm', 'CSp'],
#  'RHEA:16848': ['CS', 'CSm', 'CSp'],
#  'RHEA:16845': ['CS', 'CSm', 'CSp'],
#  'RHEA:20608': ['CSND'],
#  'RHEA:20607': ['CSND'],
#  'RHEA:20605': ['CSND'],
#  'RHEA:20606': ['CSND'],
#  'RHEA:29936': ['CSNt2pp', 'CSNt2'],
#  'RHEA:29938': ['CSNt2pp', 'CSNt2'],
#  'RHEA:29935': ['CSNt2pp', 'CSNt2'],
#  'RHEA:29937': ['CSNt2pp', 'CSNt2'],
#  'RHEA:30084': ['CU1Opp'],
#  'RHEA:30083': ['CU1Opp'],
#  'RHEA:30086': ['CU1Opp'],
#  'RHEA:30085': ['CU1Opp'],
#  'RHEA:16881': ['CYANST', 'CYANSTpp', 'CYANSTm'],
#  'RHEA:16882': ['CYANST', 'CYANSTpp', 'CYANSTm'],
#  'RHEA:16883': ['CYANST', 'CYANSTpp', 'CYANSTm'],
#  'RHEA:16884': ['CYANST', 'CYANSTpp', 'CYANSTm'],
#  'RHEA:11123': ['CYNTAH'],
#  'RHEA:11121': ['CYNTAH'],
#  'RHEA:11122': ['CYNTAH'],
#  'RHEA:11120': ['CYNTAH'],
#  'RHEA:13968': ['CYSTL', 'CYSTLp', 'CBL'],
#  'RHEA:13967': ['CYSTL', 'CYSTLp', 'CBL'],
#  'RHEA:13966': ['CYSTL', 'CYSTLp', 'CBL'],
#  'RHEA:13965': ['CYSTL', 'CYSTLp', 'CBL'],
#  'RHEA:29785': ['CYSabc2pp', 'CYSabc', 'CYSabcpp'],
#  'RHEA:29786': ['CYSabc2pp', 'CYSabc', 'CYSabcpp'],
#  'RHEA:32797': ['CYSabc2pp', 'CYSabc', 'CYSabcpp'],
#  'RHEA:32796': ['CYSabc2pp', 'CYSabc', 'CYSabcpp'],
#  'RHEA:32795': ['CYSabc2pp', 'CYSabc', 'CYSabcpp'],
#  'RHEA:29783': ['CYSabc2pp', 'CYSabc', 'CYSabcpp'],
#  'RHEA:29784': ['CYSabc2pp', 'CYSabc', 'CYSabcpp'],
#  'RHEA:32798': ['CYSabc2pp', 'CYSabc', 'CYSabcpp'],
#  'RHEA:16069': ['CYTD', 'CYTDn'],
#  'RHEA:16072': ['CYTD', 'CYTDn'],
#  'RHEA:16070': ['CYTD', 'CYTDn'],
#  'RHEA:16071': ['CYTD', 'CYTDn'],
#  'RHEA:29985': ['CYTDt2pp', 'CYTDt2'],
#  'RHEA:29983': ['CYTDt2pp', 'CYTDt2'],
#  'RHEA:29984': ['CYTDt2pp', 'CYTDt2'],
#  'RHEA:29986': ['CYTDt2pp', 'CYTDt2'],
#  'RHEA:29979': ['DADNt2pp', 'DADNt2'],
#  'RHEA:29980': ['DADNt2pp', 'DADNt2'],
#  'RHEA:29981': ['DADNt2pp', 'DADNt2'],
#  'RHEA:29982': ['DADNt2pp', 'DADNt2'],
#  'RHEA:28905': ['DALAt2pp', 'DALAt2r', 'DALAt2rL'],
#  'RHEA:28906': ['DALAt2pp', 'DALAt2r', 'DALAt2rL'],
#  'RHEA:28903': ['DALAt2pp', 'DALAt2r', 'DALAt2rL'],
#  'RHEA:28904': ['DALAt2pp', 'DALAt2r', 'DALAt2rL'],
#  'RHEA:15102': ['DAPDC'],
#  'RHEA:15104': ['DAPDC'],
#  'RHEA:15101': ['DAPDC'],
#  'RHEA:15103': ['DAPDC'],
#  'RHEA:22681': ['DCTPD'],
#  'RHEA:22683': ['DCTPD'],
#  'RHEA:22682': ['DCTPD'],
#  'RHEA:22680': ['DCTPD'],
#  'RHEA:13436': ['DCYTD', 'DCYTDn'],
#  'RHEA:13435': ['DCYTD', 'DCYTDn'],
#  'RHEA:13434': ['DCYTD', 'DCYTDn'],
#  'RHEA:13433': ['DCYTD', 'DCYTDn'],
#  'RHEA:29978': ['DCYTt2pp', 'DCYTt2'],
#  'RHEA:29975': ['DCYTt2pp', 'DCYTt2'],
#  'RHEA:29977': ['DCYTt2pp', 'DCYTt2'],
#  'RHEA:29976': ['DCYTt2pp', 'DCYTt2'],
#  'RHEA:29946': ['DDGLCNt2rpp', 'DDGLCNt2r'],
#  'RHEA:29944': ['DDGLCNt2rpp', 'DDGLCNt2r'],
#  'RHEA:29945': ['DDGLCNt2rpp', 'DDGLCNt2r'],
#  'RHEA:29943': ['DDGLCNt2rpp', 'DDGLCNt2r'],
#  'RHEA:14797': ['DDGLK'],
#  'RHEA:14799': ['DDGLK'],
#  'RHEA:14798': ['DDGLK'],
#  'RHEA:14800': ['DDGLK'],
#  'RHEA:12700': ['DGK1'],
#  'RHEA:12697': ['DGK1'],
#  'RHEA:12699': ['DGK1'],
#  'RHEA:12698': ['DGK1'],
#  'RHEA:34865': ['DHACOAH'],
#  'RHEA:34866': ['DHACOAH'],
#  'RHEA:34863': ['DHACOAH'],
#  'RHEA:34864': ['DHACOAH'],
#  'RHEA:24810': ['DHAD1', 'DHAD1m', 'DHAD_3mob_h'],
#  'RHEA:24809': ['DHAD1', 'DHAD1m', 'DHAD_3mob_h'],
#  'RHEA:24811': ['DHAD1', 'DHAD1m', 'DHAD_3mob_h'],
#  'RHEA:24812': ['DHAD1', 'DHAD1m', 'DHAD_3mob_h'],
#  'RHEA:23827': ['DHBD'],
#  'RHEA:23825': ['DHBD'],
#  'RHEA:23826': ['DHBD'],
#  'RHEA:23824': ['DHBD'],
#  'RHEA:25068': ['DHCIND'],
#  'RHEA:25067': ['DHCIND'],
#  'RHEA:25066': ['DHCIND'],
#  'RHEA:25069': ['DHCIND'],
#  'RHEA:15011': ['DHFR', 'DHFRim'],
#  'RHEA:15009': ['DHFR', 'DHFRim'],
#  'RHEA:15012': ['DHFR', 'DHFRim'],
#  'RHEA:15010': ['DHFR', 'DHFRim'],
#  'RHEA:23587': ['DHFS', 'DHFS_1'],
#  'RHEA:23585': ['DHFS', 'DHFS_1'],
#  'RHEA:23584': ['DHFS', 'DHFS_1'],
#  'RHEA:23586': ['DHFS', 'DHFS_1'],
#  'RHEA:30100': ['DHNAOT4'],
#  'RHEA:30101': ['DHNAOT4'],
#  'RHEA:30099': ['DHNAOT4'],
#  'RHEA:30102': ['DHNAOT4'],
#  'RHEA:28689': ['DHORD2'],
#  'RHEA:28688': ['DHORD2'],
#  'RHEA:28687': ['DHORD2'],
#  'RHEA:28690': ['DHORD2'],
#  'RHEA:21870': ['DHPPDA2'],
#  'RHEA:21869': ['DHPPDA2'],
#  'RHEA:21871': ['DHPPDA2'],
#  'RHEA:21868': ['DHPPDA2'],
#  'RHEA:17866': ['DHPTDNR'],
#  'RHEA:17868': ['DHPTDNR'],
#  'RHEA:17865': ['DHPTDNR'],
#  'RHEA:17867': ['DHPTDNR'],
#  'RHEA:21971': ['DHQS', 'DHQS_1'],
#  'RHEA:21970': ['DHQS', 'DHQS_1'],
#  'RHEA:21969': ['DHQS', 'DHQS_1'],
#  'RHEA:21968': ['DHQS', 'DHQS_1'],
#  'RHEA:30103': ['DKGLCNR2x'],
#  'RHEA:30104': ['DKGLCNR2x'],
#  'RHEA:30106': ['DKGLCNR2x'],
#  'RHEA:30105': ['DKGLCNR2x'],
#  'RHEA:27635': ['DKGLCNR2y'],
#  'RHEA:27637': ['DKGLCNR2y'],
#  'RHEA:27636': ['DKGLCNR2y'],
#  'RHEA:27634': ['DKGLCNR2y'],
#  'RHEA:22408': ['DMATT', 'DMATTx', 'GPPSh'],
#  'RHEA:22411': ['DMATT', 'DMATTx', 'GPPSh'],
#  'RHEA:22410': ['DMATT', 'DMATTx', 'GPPSh'],
#  'RHEA:22409': ['DMATT', 'DMATTx', 'GPPSh'],
#  'RHEA:29205': ['DMSOR1'],
#  'RHEA:29203': ['DMSOR1'],
#  'RHEA:29204': ['DMSOR1'],
#  'RHEA:29206': ['DMSOR1'],
#  'RHEA:30588': ['DMSOR2'],
#  'RHEA:30587': ['DMSOR2'],
#  'RHEA:30590': ['DMSOR2'],
#  'RHEA:30589': ['DMSOR2'],
#  'RHEA:16234': ['DPR', 'DPRm', 'PNORn'],
#  'RHEA:16233': ['DPR', 'DPRm', 'PNORn'],
#  'RHEA:16236': ['DPR', 'DPRm', 'PNORn'],
#  'RHEA:16235': ['DPR', 'DPRm', 'PNORn'],
#  'RHEA:30110': ['DSERDHr'],
#  'RHEA:30109': ['DSERDHr'],
#  'RHEA:30108': ['DSERDHr'],
#  'RHEA:30107': ['DSERDHr'],
#  'RHEA:13518': ['DTMPK', 'DTMPKm'],
#  'RHEA:13520': ['DTMPK', 'DTMPKm'],
#  'RHEA:13517': ['DTMPK', 'DTMPKm'],
#  'RHEA:13519': ['DTMPK', 'DTMPKm'],
#  'RHEA:28209': ['DURIK1', 'DURIK1m'],
#  'RHEA:28206': ['DURIK1', 'DURIK1m'],
#  'RHEA:28208': ['DURIK1', 'DURIK1m'],
#  'RHEA:28207': ['DURIK1', 'DURIK1m'],
#  'RHEA:29970': ['DURIt2pp', 'DURIt2'],
#  'RHEA:29967': ['DURIt2pp', 'DURIt2'],
#  'RHEA:29969': ['DURIt2pp', 'DURIt2'],
#  'RHEA:29968': ['DURIt2pp', 'DURIt2'],
#  'RHEA:10249': ['DUTPDP', 'DUTPDPm', 'DUTPDPn'],
#  'RHEA:10248': ['DUTPDP', 'DUTPDPm', 'DUTPDPn'],
#  'RHEA:10251': ['DUTPDP', 'DUTPDPm', 'DUTPDPn'],
#  'RHEA:10250': ['DUTPDP', 'DUTPDPm', 'DUTPDPn'],
#  'RHEA:13719': ['DXPRIi', 'DXRI'],
#  'RHEA:13720': ['DXPRIi', 'DXRI'],
#  'RHEA:13717': ['DXPRIi', 'DXRI'],
#  'RHEA:13718': ['DXPRIi', 'DXRI'],
#  'RHEA:12057': ['E4PD'],
#  'RHEA:12058': ['E4PD'],
#  'RHEA:12059': ['E4PD'],
#  'RHEA:12056': ['E4PD'],
#  'RHEA:26561': ['ECOAH1', 'ECOAH1_1', 'ECOAH1m', 'ECOAH1x'],
#  'RHEA:26560': ['ECOAH1', 'ECOAH1_1', 'ECOAH1m', 'ECOAH1x'],
#  'RHEA:26558': ['ECOAH1', 'ECOAH1_1', 'ECOAH1m', 'ECOAH1x'],
#  'RHEA:26559': ['ECOAH1', 'ECOAH1_1', 'ECOAH1m', 'ECOAH1x'],
#  'RHEA:30550': ['ECOAH2', 'ECOAH2m', 'ECOAH2_1'],
#  'RHEA:30549': ['ECOAH2', 'ECOAH2m', 'ECOAH2_1'],
#  'RHEA:30547': ['ECOAH2', 'ECOAH2m', 'ECOAH2_1'],
#  'RHEA:30548': ['ECOAH2', 'ECOAH2m', 'ECOAH2_1'],
#  'RHEA:31191': ['ECOAH4', 'ECOAH4p', 'ECOAH4m'],
#  'RHEA:31194': ['ECOAH4', 'ECOAH4p', 'ECOAH4m'],
#  'RHEA:31192': ['ECOAH4', 'ECOAH4p', 'ECOAH4m'],
#  'RHEA:31193': ['ECOAH4', 'ECOAH4p', 'ECOAH4m'],
#  'RHEA:31172': ['ECOAH6', 'ECOAH6p', 'ECOAH6m'],
#  'RHEA:31174': ['ECOAH6', 'ECOAH6p', 'ECOAH6m'],
#  'RHEA:31173': ['ECOAH6', 'ECOAH6p', 'ECOAH6m'],
#  'RHEA:31171': ['ECOAH6', 'ECOAH6p', 'ECOAH6m'],
#  'RHEA:28020': ['ENTERES'],
#  'RHEA:28019': ['ENTERES'],
#  'RHEA:28021': ['ENTERES'],
#  'RHEA:28018': ['ENTERES'],
#  'RHEA:30114': ['ENTERES2'],
#  'RHEA:30111': ['ENTERES2'],
#  'RHEA:30112': ['ENTERES2'],
#  'RHEA:30113': ['ENTERES2'],
#  'RHEA:15314': ['ETHAAL'],
#  'RHEA:15315': ['ETHAAL'],
#  'RHEA:15313': ['ETHAAL'],
#  'RHEA:15316': ['ETHAAL'],
#  'RHEA:32749': ['ETHAtex', 'SK_etha_c', 'EX_etha_e', 'ETHAt'],
#  'RHEA:32748': ['ETHAtex', 'SK_etha_c', 'EX_etha_e', 'ETHAt'],
#  'RHEA:32747': ['ETHAtex', 'SK_etha_c', 'EX_etha_e', 'ETHAt'],
#  'RHEA:32750': ['ETHAtex', 'SK_etha_c', 'EX_etha_e', 'ETHAt'],
#  'RHEA:35268': ['ETOHtex',
#   'ETOHtrpp',
#   'ETOHtx',
#   'EX_etoh_e',
#   'ETOHt',
#   'ETOHtm',
#   'ETOHth'],
#  'RHEA:35270': ['ETOHtex',
#   'ETOHtrpp',
#   'ETOHtx',
#   'EX_etoh_e',
#   'ETOHt',
#   'ETOHtm',
#   'ETOHth'],
#  'RHEA:35267': ['ETOHtex',
#   'ETOHtrpp',
#   'ETOHtx',
#   'EX_etoh_e',
#   'ETOHt',
#   'ETOHtm',
#   'ETOHth'],
#  'RHEA:35269': ['ETOHtex',
#   'ETOHtrpp',
#   'ETOHtx',
#   'EX_etoh_e',
#   'ETOHt',
#   'ETOHtm',
#   'ETOHth'],
#  'RHEA:28004': ['F6PA'],
#  'RHEA:28003': ['F6PA'],
#  'RHEA:28005': ['F6PA'],
#  'RHEA:28002': ['F6PA'],
#  'RHEA:16648': ['FACOAE160', 'PTE2x'],
#  'RHEA:16647': ['FACOAE160', 'PTE2x'],
#  'RHEA:16645': ['FACOAE160', 'PTE2x'],
#  'RHEA:16646': ['FACOAE160', 'PTE2x'],
#  'RHEA:30142': ['FACOAE180', 'PTE8x', 'RE0344M'],
#  'RHEA:30140': ['FACOAE180', 'PTE8x', 'RE0344M'],
#  'RHEA:30139': ['FACOAE180', 'PTE8x', 'RE0344M'],
#  'RHEA:30141': ['FACOAE180', 'PTE8x', 'RE0344M'],
#  'RHEA:30144': ['FACOAE80', 'PTE9x'],
#  'RHEA:30145': ['FACOAE80', 'PTE9x'],
#  'RHEA:30143': ['FACOAE80', 'PTE9x'],
#  'RHEA:30146': ['FACOAE80', 'PTE9x'],
#  'RHEA:51720': ['FACOAL180t2pp'],
#  'RHEA:51722': ['FACOAL180t2pp'],
#  'RHEA:51721': ['FACOAL180t2pp'],
#  'RHEA:51723': ['FACOAL180t2pp'],
#  'RHEA:30152': ['FADRx2'],
#  'RHEA:30153': ['FADRx2'],
#  'RHEA:30154': ['FADRx2'],
#  'RHEA:30151': ['FADRx2'],
#  'RHEA:19988': ['FALDH2'],
#  'RHEA:19987': ['FALDH2'],
#  'RHEA:19986': ['FALDH2'],
#  'RHEA:19985': ['FALDH2'],
#  'RHEA:14729': ['FBA'],
#  'RHEA:14732': ['FBA'],
#  'RHEA:14730': ['FBA'],
#  'RHEA:14731': ['FBA'],
#  'RHEA:11065': ['FBP'],
#  'RHEA:11064': ['FBP'],
#  'RHEA:11066': ['FBP'],
#  'RHEA:11067': ['FBP'],
#  'RHEA:12376': ['FCLK'],
#  'RHEA:12379': ['FCLK'],
#  'RHEA:12377': ['FCLK'],
#  'RHEA:12378': ['FCLK'],
#  'RHEA:22584': ['FCLT', 'FCLTm', 'FCLT_1', 'FCLT_2'],
#  'RHEA:22586': ['FCLT', 'FCLTm', 'FCLT_1', 'FCLT_2'],
#  'RHEA:22587': ['FCLT', 'FCLTm', 'FCLT_1', 'FCLT_2'],
#  'RHEA:22585': ['FCLT', 'FCLTm', 'FCLT_1', 'FCLT_2'],
#  'RHEA:29075': ['FDH4pp'],
#  'RHEA:29078': ['FDH4pp'],
#  'RHEA:29076': ['FDH4pp'],
#  'RHEA:29077': ['FDH4pp'],
#  'RHEA:29309': ['FDMO2'],
#  'RHEA:29310': ['FDMO2'],
#  'RHEA:29308': ['FDMO2'],
#  'RHEA:29307': ['FDMO2'],
#  'RHEA:29730': ['FDMO3'],
#  'RHEA:29729': ['FDMO3'],
#  'RHEA:29727': ['FDMO3'],
#  'RHEA:29728': ['FDMO3'],
#  'RHEA:29581': ['FE2t2pp', 'FE2tm', 'FE2DMT1'],
#  'RHEA:29580': ['FE2t2pp', 'FE2tm', 'FE2DMT1'],
#  'RHEA:29579': ['FE2t2pp', 'FE2tm', 'FE2DMT1'],
#  'RHEA:29582': ['FE2t2pp', 'FE2tm', 'FE2DMT1'],
#  'RHEA:30158': ['FE3Ri'],
#  'RHEA:30156': ['FE3Ri'],
#  'RHEA:30157': ['FE3Ri'],
#  'RHEA:30155': ['FE3Ri'],
#  'RHEA:16548': ['FORCT'],
#  'RHEA:16546': ['FORCT'],
#  'RHEA:16545': ['FORCT'],
#  'RHEA:16547': ['FORCT'],
#  'RHEA:29679': ['FORtex',
#   'FORtppi',
#   'FORtm',
#   'FORtr',
#   'FORtrn',
#   'EX_for_e',
#   'FORt',
#   'SK_for_c'],
#  'RHEA:29680': ['FORtex',
#   'FORtppi',
#   'FORtm',
#   'FORtr',
#   'FORtrn',
#   'EX_for_e',
#   'FORt',
#   'SK_for_c'],
#  'RHEA:29682': ['FORtex',
#   'FORtppi',
#   'FORtm',
#   'FORtr',
#   'FORtrn',
#   'EX_for_e',
#   'FORt',
#   'SK_for_c'],
#  'RHEA:29681': ['FORtex',
#   'FORtppi',
#   'FORtm',
#   'FORtr',
#   'FORtrn',
#   'EX_for_e',
#   'FORt',
#   'SK_for_c'],
#  'RHEA:29217': ['FRD2'],
#  'RHEA:29216': ['FRD2'],
#  'RHEA:29215': ['FRD2'],
#  'RHEA:29218': ['FRD2'],
#  'RHEA:28873': ['FRUURt2rpp'],
#  'RHEA:28872': ['FRUURt2rpp'],
#  'RHEA:28874': ['FRUURt2rpp'],
#  'RHEA:28871': ['FRUURt2rpp'],
#  'RHEA:20221': ['FTHFLi', 'FTHFLmi'],
#  'RHEA:20223': ['FTHFLi', 'FTHFLmi'],
#  'RHEA:20224': ['FTHFLi', 'FTHFLmi'],
#  'RHEA:20222': ['FTHFLi', 'FTHFLmi'],
#  'RHEA:12462': ['FUM', 'FUMm'],
#  'RHEA:12461': ['FUM', 'FUMm'],
#  'RHEA:12460': ['FUM', 'FUMm'],
#  'RHEA:12463': ['FUM', 'FUMm'],
#  'RHEA:35103': ['FUSAtex', 'EX_fusa_e'],
#  'RHEA:35106': ['FUSAtex', 'EX_fusa_e'],
#  'RHEA:35105': ['FUSAtex', 'EX_fusa_e'],
#  'RHEA:35104': ['FUSAtex', 'EX_fusa_e'],
#  'RHEA:19934': ['G1PPpp', 'G1PP'],
#  'RHEA:19935': ['G1PPpp', 'G1PP'],
#  'RHEA:19933': ['G1PPpp', 'G1PP'],
#  'RHEA:19936': ['G1PPpp', 'G1PP'],
#  'RHEA:15226': ['G1PTT'],
#  'RHEA:15225': ['G1PTT'],
#  'RHEA:15227': ['G1PTT'],
#  'RHEA:15228': ['G1PTT'],
#  'RHEA:14267': ['G1SAT', 'G1SAT_1'],
#  'RHEA:14268': ['G1SAT', 'G1SAT_1'],
#  'RHEA:14266': ['G1SAT', 'G1SAT_1'],
#  'RHEA:14265': ['G1SAT', 'G1SAT_1'],
#  'RHEA:28752': ['G3PD5'],
#  'RHEA:28751': ['G3PD5'],
#  'RHEA:28754': ['G3PD5'],
#  'RHEA:28753': ['G3PD5'],
#  'RHEA:32918': ['G3PItex', 'G3PIt', 'EX_g3pi_e'],
#  'RHEA:32915': ['G3PItex', 'G3PIt', 'EX_g3pi_e'],
#  'RHEA:32917': ['G3PItex', 'G3PIt', 'EX_g3pi_e'],
#  'RHEA:32916': ['G3PItex', 'G3PIt', 'EX_g3pi_e'],
#  'RHEA:15844': ['G6PDH2r', 'G6PDH2er'],
#  'RHEA:15841': ['G6PDH2r', 'G6PDH2er'],
#  'RHEA:15843': ['G6PDH2r', 'G6PDH2er'],
#  'RHEA:15842': ['G6PDH2r', 'G6PDH2er'],
#  'RHEA:16691': ['G6PP', 'G6PPer'],
#  'RHEA:16690': ['G6PP', 'G6PPer'],
#  'RHEA:16692': ['G6PP', 'G6PPer'],
#  'RHEA:16689': ['G6PP', 'G6PPer'],
#  'RHEA:16006': ['GALCTD', 'GALCTD_1'],
#  'RHEA:16007': ['GALCTD', 'GALCTD_1'],
#  'RHEA:16008': ['GALCTD', 'GALCTD_1'],
#  'RHEA:16005': ['GALCTD', 'GALCTD_1'],
#  'RHEA:28678': ['GALM2pp', 'GALM2'],
#  'RHEA:28677': ['GALM2pp', 'GALM2'],
#  'RHEA:28676': ['GALM2pp', 'GALM2'],
#  'RHEA:28675': ['GALM2pp', 'GALM2'],
#  'RHEA:29020': ['GALt2pp', 'GALth', 'GALt2'],
#  'RHEA:29022': ['GALt2pp', 'GALth', 'GALt2'],
#  'RHEA:29019': ['GALt2pp', 'GALth', 'GALt2'],
#  'RHEA:29021': ['GALt2pp', 'GALth', 'GALt2'],
#  'RHEA:24832': ['GART'],
#  'RHEA:24830': ['GART'],
#  'RHEA:24829': ['GART'],
#  'RHEA:24831': ['GART'],
#  'RHEA:27980': ['GDPMNP'],
#  'RHEA:27979': ['GDPMNP'],
#  'RHEA:27978': ['GDPMNP'],
#  'RHEA:27981': ['GDPMNP'],
#  'RHEA:19740': ['GGGABAH'],
#  'RHEA:19739': ['GGGABAH'],
#  'RHEA:19738': ['GGGABAH'],
#  'RHEA:19737': ['GGGABAH'],
#  'RHEA:15482': ['GHMT2r', 'GHMT2rm'],
#  'RHEA:15483': ['GHMT2r', 'GHMT2rm'],
#  'RHEA:15481': ['GHMT2r', 'GHMT2rm'],
#  'RHEA:15484': ['GHMT2r', 'GHMT2rm'],
#  'RHEA:27729': ['GLCRAL', 'GLCRAL_1'],
#  'RHEA:27727': ['GLCRAL', 'GLCRAL_1'],
#  'RHEA:27728': ['GLCRAL', 'GLCRAL_1'],
#  'RHEA:27726': ['GLCRAL', 'GLCRAL_1'],
#  'RHEA:14574': ['GLCRD', 'GLCRD_1'],
#  'RHEA:14575': ['GLCRD', 'GLCRD_1'],
#  'RHEA:14573': ['GLCRD', 'GLCRD_1'],
#  'RHEA:14576': ['GLCRD', 'GLCRD_1'],
#  'RHEA:12123': ['GLGC', 'GLPThi'],
#  'RHEA:12120': ['GLGC', 'GLPThi'],
#  'RHEA:12121': ['GLGC', 'GLPThi'],
#  'RHEA:12122': ['GLGC', 'GLPThi'],
#  'RHEA:16169': ['GLNS', 'GALh', 'GALm'],
#  'RHEA:16170': ['GLNS', 'GALh', 'GALm'],
#  'RHEA:16171': ['GLNS', 'GALh', 'GALm'],
#  'RHEA:16172': ['GLNS', 'GALh', 'GALm'],
#  'RHEA:13286': ['GLUCYS', 'GCL'],
#  'RHEA:13285': ['GLUCYS', 'GCL'],
#  'RHEA:13288': ['GLUCYS', 'GCL'],
#  'RHEA:13287': ['GLUCYS', 'GCL'],
#  'RHEA:17788': ['GLUDC', 'ARGDh'],
#  'RHEA:17787': ['GLUDC', 'ARGDh'],
#  'RHEA:17785': ['GLUDC', 'ARGDh'],
#  'RHEA:17786': ['GLUDC', 'ARGDh'],
#  'RHEA:15891': ['GLUNpp', 'GAM', 'GLUN', 'GLUNm'],
#  'RHEA:15889': ['GLUNpp', 'GAM', 'GLUN', 'GLUNm'],
#  'RHEA:15892': ['GLUNpp', 'GAM', 'GLUN', 'GLUNm'],
#  'RHEA:15890': ['GLUNpp', 'GAM', 'GLUN', 'GLUNm'],
#  'RHEA:14907': ['GLUPRT', 'PRDPARh'],
#  'RHEA:14905': ['GLUPRT', 'PRDPARh'],
#  'RHEA:14908': ['GLUPRT', 'PRDPARh'],
#  'RHEA:14906': ['GLUPRT', 'PRDPARh'],
#  'RHEA:12813': ['GLUR'],
#  'RHEA:12815': ['GLUR'],
#  'RHEA:12816': ['GLUR'],
#  'RHEA:12814': ['GLUR'],
#  'RHEA:15501': ['GLUSy', 'GLUS_nadph'],
#  'RHEA:15504': ['GLUSy', 'GLUS_nadph'],
#  'RHEA:15502': ['GLUSy', 'GLUS_nadph'],
#  'RHEA:15503': ['GLUSy', 'GLUS_nadph'],
#  'RHEA:29036': ['GLUabcpp', 'GLUabc', 'GLUVESSEC'],
#  'RHEA:29037': ['GLUabcpp', 'GLUabc', 'GLUVESSEC'],
#  'RHEA:29035': ['GLUabcpp', 'GLUabc', 'GLUVESSEC'],
#  'RHEA:29038': ['GLUabcpp', 'GLUabc', 'GLUVESSEC'],
#  'RHEA:10136': ['GLXCL', 'GLXCBL'],
#  'RHEA:10137': ['GLXCL', 'GLXCBL'],
#  'RHEA:10139': ['GLXCL', 'GLXCBL'],
#  'RHEA:10138': ['GLXCL', 'GLXCBL'],
#  'RHEA:32783': ['GLYBabcpp', 'GLYBabc'],
#  'RHEA:32786': ['GLYBabcpp', 'GLYBabc'],
#  'RHEA:32784': ['GLYBabcpp', 'GLYBabc'],
#  'RHEA:32785': ['GLYBabcpp', 'GLYBabc'],
#  'RHEA:28943': ['GLYBtex', 'GLYBtm', 'EX_glyb_e'],
#  'RHEA:28946': ['GLYBtex', 'GLYBtm', 'EX_glyb_e'],
#  'RHEA:28945': ['GLYBtex', 'GLYBtm', 'EX_glyb_e'],
#  'RHEA:28944': ['GLYBtex', 'GLYBtm', 'EX_glyb_e'],
#  'RHEA:29018': ['GLYC3Pt6pp', 'GLYC3Pt6', 'r2472'],
#  'RHEA:29017': ['GLYC3Pt6pp', 'GLYC3Pt6', 'r2472'],
#  'RHEA:29015': ['GLYC3Pt6pp', 'GLYC3Pt6', 'r2472'],
#  'RHEA:29016': ['GLYC3Pt6pp', 'GLYC3Pt6', 'r2472'],
#  ...}

# %%
rxn_bigg[rxn_bigg.bigg_id.isin(['DM_4crsol_c', 'CREStex', 'EX_4crsol_e'])]
# Out:
#            bigg_id                                               name  \
# 0      DM_4crsol_c      Sink needed to allow p-Cresol to leave system
# 2683       CREStex  P-cresol transport vis diffusion (extra-organi...
# 16669  EX_4crsol_e                                  P-Cresol exchange
#
#              reaction_string  \
# 0              4crsol_c <->
# 2683   4crsol_p <-> 4crsol_e
# 16669          4crsol_e <->
#
#                                               model_list  \
# 0      iEcDH1_1363; iJO1366; iE2348C_1286; iECB_1328;...
# 2683                                              iAF987
# 16669                                             iAF987
#
#                                           database_links  \
# 0      RHEA: http://identifiers.org/rhea/35071; RHEA:...
# 2683   RHEA: http://identifiers.org/rhea/35071; RHEA:...
# 16669  RHEA: http://identifiers.org/rhea/35071; RHEA:...
#
#                  old_bigg_ids  \
# 0      DM_4CRSOL; DM_4crsol_c
# 2683                  CREStex
# 16669             EX_4crsol_e
#
#                                               rhea_link
# 0      [RHEA:35072, RHEA:35073, RHEA:35071, RHEA:35074]
# 2683   [RHEA:35072, RHEA:35073, RHEA:35071, RHEA:35074]
# 16669  [RHEA:35072, RHEA:35073, RHEA:35071, RHEA:35074]
